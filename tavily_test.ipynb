# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_5320\1690773881.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults
# True

# %%
tool = TavilySearchResults(max_results=2)
results = tool.invoke({"query": 'ChatGPT version releases and updates from 2022 to 2026'})
results
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_5320\1187185310.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=2)
# [{'title': 'ChatGPT - Wikipedia',
#   'url': 'https://en.wikipedia.org/wiki/ChatGPT',
#   'content': 'Generative AI chatbot by OpenAI\n\n| ChatGPT |\n\n| Developer | OpenAI |\n| Release | November 30, 2022 (3 years ago) (2022-11-30) |\n| Stable release | June 18, 2026 (2 months ago) (2026-06-18) |\n|  |\n| Engine | GPT-5.6 |\n| Operating system |  Web platform  iOS  Android "Android (operating system)")  macOS  Windows  iPadOS |\n| Platform | Cloud computing platforms |\n| Available in | 59 languages |\n| Type |  Chatbot  Large language model  Generative pre-trained transformer |\n| License | Proprietary service |\n| Website | chatgpt.com |\n\n \n\n|  | [...] | Version | Release date | Status in ChatGPT | Description |\n| GPT-3.5 | November 2022 | Discontinued | The first model used in ChatGPT. |\n| GPT-4 | March 2023 | Discontinued | Larger than GPT-3.5. |\n| GPT-4o | May 2024 | Discontinued | Capable of processing text, image, audio, and video, GPT-4o is faster and more capable than GPT-4. Was accused of being particularly sycophantic. Its removal from ChatGPT led to backlash from users attached to its personality. The variant GPT-4o mini replaced GPT-3.5 in the July 2024 version of ChatGPT. |\n| o1 | December 2024 | Discontinued | An early reasoning model (one that can reason through a problem before answering). Slower, but can solve more complex problems, particularly in math, coding and science. |',
#   'score': 0.9489978},
#  {'title': 'ChatGPT Version History List, Changelog & Latest Releases',
#   'url': 'https://objects.ws/blog/chatgpt-version-history',
#   'content': '| ChatGPT 5.3 | GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was introduced in March 2026. | This version was handy for enhancing full-cycle software development along with collaboration. It also delighted users through more accurate, logical answers. |\n| ChatGPT 5.2 | December 2025 | The version, GPT-5.2, favored routine activities and learning. Users were allowed to ask technical questions in a conversational tone. |\n| ChatGPT 5.1 | November 2025 | Answers have become smarter and conversational. GPT-5.1 Instant and GPT 5.1 Thinking were launched to provide users with more simplified and precise responses. |\n| ChatGPT 5 | August 2025 | GPT-5 demonstrated tool coordination, context management, and improved reasoning. | [...] | Introducing OpenAI Operator Agent | January 2025 | The agent benefited from GPT-4’s vision and reasoning capabilities to enhance interactions with web pages. |\n| Scheduled Tasks in ChatGPT | January 2025 | This update helped automate schedule tasks. Users could configure notifications, daily reports, and AI-generated messages. |\n| OpenAI o3 Preview | December 2024 | This model offered enhancements in problem-solving, reliability, and self-correction. |\n| Full o1 Model Launch | December 2024 | This model was more productive than the previous o1-preview model. Users availed themselves of features such as function calling, image analysis, and the “Reasoning Effort” parameter. | [...] | Sora Launch | December 2024 | This update introduced the “Text-to-Video Generation” feature. It allowed users to produce high-quality 20-second 1080p videos. |\n| ChatGPT Pro Launch | December 2024 | A paid subscription package at $200 per month was introduced for users who wanted unrestricted access to OpenAI’s most sophisticated AI models. |\n| GPT-4 Turbo & Custom GPTs | November 2024 | GPT-4 Turbo was a cost-effective, useful, and top-notch variant of GPT-4. Custom GPTs helped users create personalized ChatGPTs without any programming skills. |',
#   'score': 0.94174546}]
